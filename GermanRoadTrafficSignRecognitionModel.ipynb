# %%
import tensorflow as tf
from sklearn import model_selection
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Dense,
    Dropout,
    MaxPooling2D,
    Conv2D,
    Flatten,
    BatchNormalization,
    Input,
    Average,
)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model

import matplotlib.pyplot as plt
import gradio as gr
import pandas as pd
import numpy as np
from numpy import save
from numpy import load

# %%
def load_dataset():
    X_train = load("X_GTS_train_copy.npy")
    Y_train = load("Y_GTS_train_copy.npy")
    X_test = load("X_GTS_test_copy.npy")
    Y_test = load("Y_GTS_test_copy.npy")
    string_class_labels = load("Class_labels_copy.npy")
    Y_train = Y_train.astype(np.float)
    Y_test = Y_test.astype(np.float)

    X_train, X_val, Y_train, Y_val = model_selection.train_test_split(
        X_train, Y_train, test_size=0.3, random_state=42, shuffle=True
    )

    return X_train, Y_train, X_test, Y_test, string_class_labels, X_val, Y_val

# %%
X_train, Y_train, X_test, Y_test, string_class_labels, X_val, Y_val = load_dataset()

# %% [markdown]
# ![alt text](https://miro.medium.com/max/1400/1*uAeANQIOQPqWZnnuH-VEyw.jpeg "CNN")
#
# ##### source: https://towardsdatascience.com/

# %% [markdown]
# ### Image augmentation parameters

# %%
datagen = ImageDataGenerator(
    shear_range=0.15,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.15,
    horizontal_flip=True,
    vertical_flip=False,
    fill_mode="nearest")

# %% [markdown]
# ### Model and training

# %%
input_shape = X_train.shape[1:]
model_input = Input(shape=input_shape)

# %%
def func_cnn(model_input):

    x = Conv2D(filters=16, kernel_size=(3, 3), activation="relu")(model_input)
    x = Conv2D(filters=32, kernel_size=(3, 3), activation="relu")(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = BatchNormalization(axis=-1)(x)

    x = Conv2D(filters=64, kernel_size=(3, 3), activation="relu")(x)
    x = Conv2D(filters=128, kernel_size=(3, 3), activation="relu")(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = BatchNormalization(axis=-1)(x)

    x = Flatten()(x)
    x = Dense(512, activation="relu")(x)

    x = Dropout(rate=0.5)(x)

    x = Dense(43, activation="softmax")(x)

    cnn_model = Model(model_input, x, name="conv_pool_cnn")

    return cnn_model

# %%
conv_pool_cnn_model = func_cnn(model_input)

# %%
def train(model, loss, optimizer, metrics, batch_size, epochs):
    model.compile(loss=loss, optimizer=optimizer, metrics=[metrics])
    history = model.fit(
        datagen.flow(X_train, Y_train, batch_size=batch_size),
        epochs=epochs,
        validation_data=(X_val, Y_val),
    )
    return history

# %%
history_cnn = train(
    conv_pool_cnn_model, "sparse_categorical_crossentropy", "adam", "accuracy", 32, 30
)
# Out:
# Epoch 1/30
# 858/858 [==============================] - 16s 12ms/step - loss: 1.3693 - accuracy: 0.6128 - val_loss: 0.3587 - val_accuracy: 0.8761
# Epoch 2/30
# 858/858 [==============================] - 10s 11ms/step - loss: 0.4455 - accuracy: 0.8579 - val_loss: 0.1092 - val_accuracy: 0.9620
# Epoch 3/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.2884 - accuracy: 0.9063 - val_loss: 0.1907 - val_accuracy: 0.9350
# Epoch 4/30
# 858/858 [==============================] - 10s 11ms/step - loss: 0.2684 - accuracy: 0.9136 - val_loss: 0.1566 - val_accuracy: 0.9515
# Epoch 5/30
# 858/858 [==============================] - 10s 11ms/step - loss: 0.2193 - accuracy: 0.9285 - val_loss: 0.1116 - val_accuracy: 0.9602
# Epoch 6/30
# 858/858 [==============================] - 10s 11ms/step - loss: 0.2026 - accuracy: 0.9359 - val_loss: 0.0969 - val_accuracy: 0.9640
# Epoch 7/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.1871 - accuracy: 0.9402 - val_loss: 0.0656 - val_accuracy: 0.9760
# Epoch 8/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.1823 - accuracy: 0.9448 - val_loss: 0.1431 - val_accuracy: 0.9520
# Epoch 9/30
# 858/858 [==============================] - 10s 11ms/step - loss: 0.1677 - accuracy: 0.9456 - val_loss: 0.0786 - val_accuracy: 0.9725
# Epoch 10/30
# 858/858 [==============================] - 10s 11ms/step - loss: 0.1646 - accuracy: 0.9483 - val_loss: 0.0748 - val_accuracy: 0.9748
# Epoch 11/30
# 858/858 [==============================] - 10s 11ms/step - loss: 0.1694 - accuracy: 0.9477 - val_loss: 0.0742 - val_accuracy: 0.9741
# Epoch 12/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.1483 - accuracy: 0.9531 - val_loss: 0.1190 - val_accuracy: 0.9625
# Epoch 13/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.1443 - accuracy: 0.9550 - val_loss: 0.0558 - val_accuracy: 0.9823
# Epoch 14/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.1339 - accuracy: 0.9588 - val_loss: 0.0613 - val_accuracy: 0.9831
# Epoch 15/30
# 858/858 [==============================] - 11s 12ms/step - loss: 0.1259 - accuracy: 0.9597 - val_loss: 0.0431 - val_accuracy: 0.9852
# Epoch 16/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.1125 - accuracy: 0.9640 - val_loss: 0.0578 - val_accuracy: 0.9815
# Epoch 17/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.1205 - accuracy: 0.9624 - val_loss: 0.0717 - val_accuracy: 0.9789
# Epoch 18/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.1161 - accuracy: 0.9632 - val_loss: 0.0551 - val_accuracy: 0.9832
# Epoch 19/30
# 858/858 [==============================] - 11s 12ms/step - loss: 0.1031 - accuracy: 0.9684 - val_loss: 0.0406 - val_accuracy: 0.9858
# Epoch 20/30
# 858/858 [==============================] - 11s 13ms/step - loss: 0.1163 - accuracy: 0.9639 - val_loss: 0.0721 - val_accuracy: 0.9756
# Epoch 21/30
# 858/858 [==============================] - 11s 12ms/step - loss: 0.1060 - accuracy: 0.9679 - val_loss: 0.0401 - val_accuracy: 0.9868
# Epoch 22/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.0935 - accuracy: 0.9691 - val_loss: 0.0585 - val_accuracy: 0.9780
# Epoch 23/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.0924 - accuracy: 0.9707 - val_loss: 0.0240 - val_accuracy: 0.9920
# Epoch 24/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.0942 - accuracy: 0.9722 - val_loss: 0.0491 - val_accuracy: 0.9833
# Epoch 25/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.0873 - accuracy: 0.9719 - val_loss: 0.0374 - val_accuracy: 0.9898
# Epoch 26/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.0908 - accuracy: 0.9713 - val_loss: 0.0413 - val_accuracy: 0.9883
# Epoch 27/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.0848 - accuracy: 0.9733 - val_loss: 0.0393 - val_accuracy: 0.9880
# Epoch 28/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.0878 - accuracy: 0.9735 - val_loss: 0.0355 - val_accuracy: 0.9864
# Epoch 29/30
# 858/858 [==============================] - 11s 13ms/step - loss: 0.0777 - accuracy: 0.9763 - val_loss: 0.0465 - val_accuracy: 0.9827
# Epoch 30/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.0851 - accuracy: 0.9741 - val_loss: 0.0262 - val_accuracy: 0.9920

# %% [markdown]
# #### Plotting the loss and the accuracy

# %%
plt.plot(history_cnn.history["accuracy"])
plt.plot(history_cnn.history["val_accuracy"])
plt.plot(history_cnn.history["loss"])
plt.legend(["accuracy", "val_accuracy", "loss"])

# %%
conv_pool_cnn_model.summary()
# Out:
# Model: "conv_pool_cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 30, 30, 16)        448
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        4640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 14, 14, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 128)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 5, 5, 128)         512
# _________________________________________________________________
# flatten (Flatten)            (None, 3200)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1638912
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 43)                22059
# =================================================================
# Total params: 1,759,051
# Trainable params: 1,758,731
# Non-trainable params: 320
# _________________________________________________________________

# %%
score_cnn = conv_pool_cnn_model.evaluate(X_test, Y_test)
# Out:
# 395/395 [==============================] - 1s 2ms/step - loss: 0.2300 - accuracy: 0.9501

# %% [markdown]
# #### Calculating log loss for CNN model

# %%
pred_Cnn = conv_pool_cnn_model.predict(X_test)

# %%
import sklearn.metrics as metrics

log_loss_score = metrics.log_loss(Y_test, pred_Cnn)
print("Log loss score: {}".format(log_loss_score))
# Out:
# Log loss score: 0.23001238779710864

# %% [markdown]
# #### Confusion matrix

# %%
classes_x = np.argmax(pred_Cnn, axis=1)

# %%
from sklearn.metrics import confusion_matrix

cf = confusion_matrix(Y_test, classes_x)

# %%
import seaborn as sns

df_cm = pd.DataFrame(cf, index=string_class_labels, columns=string_class_labels)
plt.figure(figsize=(20, 20))
sns.heatmap(df_cm, annot=True)

# %% [markdown]
# #### Classification report

# %%
from sklearn.metrics import classification_report

print(classification_report(Y_test, classes_x))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.94      1.00      0.97        60
#          1.0       0.97      0.99      0.98       720
#          2.0       0.96      1.00      0.98       750
#          3.0       0.99      0.95      0.97       450
#          4.0       1.00      0.98      0.99       660
#          5.0       0.97      0.96      0.96       630
#          6.0       0.98      0.92      0.95       150
#          7.0       1.00      0.99      0.99       450
#          8.0       0.96      1.00      0.98       450
#          9.0       0.98      1.00      0.99       480
#         10.0       1.00      0.99      0.99       660
#         11.0       0.97      1.00      0.98       420
#         12.0       1.00      0.97      0.98       690
#         13.0       0.98      1.00      0.99       720
#         14.0       1.00      1.00      1.00       270
#         15.0       1.00      0.98      0.99       210
#         16.0       0.99      1.00      0.99       150
#         17.0       1.00      0.99      1.00       360
#         18.0       1.00      0.96      0.98       390
#         19.0       0.34      0.58      0.43        60
#         20.0       0.60      0.56      0.58        90
#         21.0       0.91      0.67      0.77        90
#         22.0       1.00      0.78      0.87       120
#         23.0       0.82      1.00      0.90       150
#         24.0       0.99      0.98      0.98        90
#         25.0       0.95      0.95      0.95       480
#         26.0       0.97      0.99      0.98       180
#         27.0       1.00      0.52      0.68        60
#         28.0       0.91      0.99      0.95       150
#         29.0       0.89      1.00      0.94        90
#         30.0       0.99      0.75      0.86       150
#         31.0       0.98      1.00      0.99       270
#         32.0       1.00      0.85      0.92        60
#         33.0       0.97      0.70      0.81       210
#         34.0       0.66      0.99      0.79       120
#         35.0       0.99      0.98      0.99       390
#         36.0       0.47      0.45      0.46       120
#         37.0       0.03      0.03      0.03        60
#         38.0       0.92      0.97      0.95       690
#         39.0       0.86      0.60      0.71        90
#         40.0       0.84      0.92      0.88        90
#         41.0       0.95      0.93      0.94        60
#         42.0       0.98      0.97      0.97        90
#
#     accuracy                           0.95     12630
#    macro avg       0.90      0.88      0.88     12630
# weighted avg       0.95      0.95      0.95     12630

# %% [markdown]
# ## Using transfer learning on VGG19

# %% [markdown]
# ![alt text](https://blog.techcraft.org/wp-content/uploads/2021/03/vgg19-architecture2.png "VGG19")
#
# ##### source: blog.techcraft.org

# %%
def func_transfer(model_input):

    vgg19_model = tf.keras.applications.VGG19(
        include_top=False,
        weights="imagenet",
        input_tensor=model_input,
        pooling=max,
        classes=43,
        classifier_activation="softmax",
    )

    for layer in vgg19_model.layers:
        layer.trainable = True

    x = BatchNormalization()(vgg19_model.output)
    x = Flatten()(x)
    x = Dense(1024, activation="sigmoid")(x)

    x = Dense(43, activation="softmax")(x)

    vg_model = Model(inputs=model_input, outputs=x, name="vgg19_transfer")

    return vg_model

# %%
vgg19_transfer_model = func_transfer(model_input)

# %%
history_vg = train(
    vgg19_transfer_model, "sparse_categorical_crossentropy", "adam", "accuracy", 32, 30
)
# Out:
# Epoch 1/30
# 858/858 [==============================] - 22s 24ms/step - loss: 2.8224 - accuracy: 0.1573 - val_loss: 2.5153 - val_accuracy: 0.1610
# Epoch 2/30
# 858/858 [==============================] - 20s 23ms/step - loss: 2.4276 - accuracy: 0.2052 - val_loss: 2.3403 - val_accuracy: 0.2098
# Epoch 3/30
# 858/858 [==============================] - 20s 24ms/step - loss: 2.2753 - accuracy: 0.2377 - val_loss: 3.9849 - val_accuracy: 0.0914
# Epoch 4/30
# 858/858 [==============================] - 20s 24ms/step - loss: 2.2129 - accuracy: 0.2533 - val_loss: 2.2509 - val_accuracy: 0.2323
# Epoch 5/30
# 858/858 [==============================] - 19s 22ms/step - loss: 1.7190 - accuracy: 0.3976 - val_loss: 2.3416 - val_accuracy: 0.2713
# Epoch 6/30
# 858/858 [==============================] - 20s 23ms/step - loss: 1.2334 - accuracy: 0.5627 - val_loss: 0.8671 - val_accuracy: 0.6778
# Epoch 7/30
# 858/858 [==============================] - 20s 23ms/step - loss: 1.0415 - accuracy: 0.6219 - val_loss: 1.0384 - val_accuracy: 0.5952
# Epoch 8/30
# 858/858 [==============================] - 20s 23ms/step - loss: 0.9014 - accuracy: 0.6770 - val_loss: 0.6000 - val_accuracy: 0.7978
# Epoch 9/30
# 858/858 [==============================] - 20s 23ms/step - loss: 0.8104 - accuracy: 0.7154 - val_loss: 0.7005 - val_accuracy: 0.7517
# Epoch 10/30
# 858/858 [==============================] - 20s 23ms/step - loss: 0.7043 - accuracy: 0.7577 - val_loss: 0.4373 - val_accuracy: 0.8494
# Epoch 11/30
# 858/858 [==============================] - 20s 23ms/step - loss: 0.5991 - accuracy: 0.7971 - val_loss: 1.0084 - val_accuracy: 0.6361
# Epoch 12/30
# 858/858 [==============================] - 20s 23ms/step - loss: 0.4897 - accuracy: 0.8306 - val_loss: 0.3003 - val_accuracy: 0.8866
# Epoch 13/30
# 858/858 [==============================] - 20s 23ms/step - loss: 0.4747 - accuracy: 0.8398 - val_loss: 0.2814 - val_accuracy: 0.8994
# Epoch 14/30
# 858/858 [==============================] - 20s 23ms/step - loss: 0.4095 - accuracy: 0.8554 - val_loss: 0.3356 - val_accuracy: 0.8746
# Epoch 15/30
# 858/858 [==============================] - 20s 23ms/step - loss: 0.3730 - accuracy: 0.8720 - val_loss: 0.1934 - val_accuracy: 0.9290
# Epoch 16/30
# 858/858 [==============================] - 20s 23ms/step - loss: 0.3466 - accuracy: 0.8805 - val_loss: 0.2032 - val_accuracy: 0.9267
# Epoch 17/30
# 858/858 [==============================] - 20s 23ms/step - loss: 0.3115 - accuracy: 0.8908 - val_loss: 0.2100 - val_accuracy: 0.9303
# Epoch 18/30
# 858/858 [==============================] - 20s 23ms/step - loss: 0.2939 - accuracy: 0.8982 - val_loss: 0.1723 - val_accuracy: 0.9329
# Epoch 19/30
# 858/858 [==============================] - 20s 23ms/step - loss: 0.2661 - accuracy: 0.9091 - val_loss: 0.4584 - val_accuracy: 0.8510
# Epoch 20/30
# 858/858 [==============================] - 20s 23ms/step - loss: 0.2571 - accuracy: 0.9119 - val_loss: 0.1179 - val_accuracy: 0.9656
# Epoch 21/30
# 858/858 [==============================] - 20s 23ms/step - loss: 0.2533 - accuracy: 0.9161 - val_loss: 0.1242 - val_accuracy: 0.9510
# Epoch 22/30
# 858/858 [==============================] - 20s 23ms/step - loss: 0.2231 - accuracy: 0.9241 - val_loss: 0.1902 - val_accuracy: 0.9274
# Epoch 23/30
# 858/858 [==============================] - 20s 23ms/step - loss: 0.2390 - accuracy: 0.9196 - val_loss: 0.1674 - val_accuracy: 0.9504
# Epoch 24/30
# 858/858 [==============================] - 20s 23ms/step - loss: 0.2438 - accuracy: 0.9216 - val_loss: 0.1966 - val_accuracy: 0.9291
# Epoch 25/30
# 858/858 [==============================] - 20s 23ms/step - loss: 0.1997 - accuracy: 0.9308 - val_loss: 0.0986 - val_accuracy: 0.9624
# Epoch 26/30
# 858/858 [==============================] - 20s 23ms/step - loss: 0.1646 - accuracy: 0.9403 - val_loss: 0.0856 - val_accuracy: 0.9708
# Epoch 27/30
# 858/858 [==============================] - 20s 23ms/step - loss: 0.1622 - accuracy: 0.9425 - val_loss: 0.0941 - val_accuracy: 0.9559
# Epoch 28/30
# 858/858 [==============================] - 19s 22ms/step - loss: 0.1777 - accuracy: 0.9377 - val_loss: 0.4247 - val_accuracy: 0.8728
# Epoch 29/30
# 858/858 [==============================] - 19s 22ms/step - loss: 0.1742 - accuracy: 0.9415 - val_loss: 0.0694 - val_accuracy: 0.9738
# Epoch 30/30
# 858/858 [==============================] - 19s 23ms/step - loss: 0.1644 - accuracy: 0.9448 - val_loss: 0.1407 - val_accuracy: 0.9495

# %%
vgg19_transfer_model.summary()
# Out:
# Model: "vgg19_transfer"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 16, 16, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 8, 8, 128)         0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 4, 4, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 1, 1, 512)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1, 1, 512)         2048
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# dense_3 (Dense)              (None, 43)                44075
# =================================================================
# Total params: 20,595,819
# Trainable params: 20,594,795
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
plt.plot(history_vg.history["accuracy"])
plt.plot(history_vg.history["val_accuracy"])
plt.plot(history_vg.history["loss"])
plt.legend(["accuracy", "val_accuracy", "loss"])

# %%
score_vg = vgg19_transfer_model.evaluate(X_test, Y_test)
# Out:
# 395/395 [==============================] - 2s 6ms/step - loss: 0.3826 - accuracy: 0.9159

# %% [markdown]
# #### Log loss for vgg19 transfer architecture model

# %%
pred_vg = vgg19_transfer_model.predict(X_test)

# %%
log_loss_score_vg = metrics.log_loss(Y_test, pred_vg)
print("Log loss score: {}".format(log_loss_score_vg))
# Out:
# Log loss score: 0.380965837967715

# %% [markdown]
# #### Confusion matrix for vgg19 model

# %%
classes_x_vg = np.argmax(pred_vg, axis=1)
cf_vg = confusion_matrix(Y_test, classes_x_vg)

df_cm_vg = pd.DataFrame(cf_vg, index=string_class_labels, columns=string_class_labels)
plt.figure(figsize=(20, 20))
sns.heatmap(df_cm_vg, annot=True)

# %% [markdown]
# #### Classification report

# %%
print(classification_report(Y_test, classes_x_vg))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.80      1.00      0.89        60
#          1.0       1.00      0.98      0.99       720
#          2.0       1.00      0.99      0.99       750
#          3.0       0.96      0.98      0.97       450
#          4.0       0.98      0.99      0.99       660
#          5.0       0.98      0.99      0.99       630
#          6.0       0.61      0.79      0.69       150
#          7.0       1.00      0.99      1.00       450
#          8.0       0.99      0.97      0.98       450
#          9.0       0.99      1.00      0.99       480
#         10.0       1.00      0.98      0.99       660
#         11.0       1.00      0.90      0.95       420
#         12.0       1.00      0.97      0.98       690
#         13.0       1.00      1.00      1.00       720
#         14.0       0.90      0.61      0.72       270
#         15.0       0.96      1.00      0.98       210
#         16.0       1.00      1.00      1.00       150
#         17.0       1.00      0.92      0.96       360
#         18.0       0.99      0.90      0.94       390
#         19.0       0.00      0.00      0.00        60
#         20.0       0.52      0.86      0.65        90
#         21.0       0.63      0.66      0.64        90
#         22.0       0.99      0.76      0.86       120
#         23.0       0.81      1.00      0.90       150
#         24.0       0.78      0.98      0.87        90
#         25.0       0.98      0.93      0.96       480
#         26.0       0.83      0.98      0.90       180
#         27.0       0.69      0.77      0.72        60
#         28.0       0.79      0.97      0.87       150
#         29.0       0.87      1.00      0.93        90
#         30.0       0.95      0.70      0.80       150
#         31.0       0.93      0.96      0.95       270
#         32.0       0.82      1.00      0.90        60
#         33.0       0.60      0.31      0.41       210
#         34.0       0.42      0.91      0.57       120
#         35.0       1.00      0.99      0.99       390
#         36.0       0.00      0.00      0.00       120
#         37.0       0.34      1.00      0.51        60
#         38.0       0.88      1.00      0.93       690
#         39.0       0.00      0.00      0.00        90
#         40.0       0.76      0.63      0.69        90
#         41.0       0.89      0.85      0.87        60
#         42.0       0.20      0.32      0.25        90
#
#     accuracy                           0.92     12630
#    macro avg       0.79      0.83      0.79     12630
# weighted avg       0.91      0.92      0.91     12630
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Average ensemble model

# %%
def ensemble_model(model_1, model_2):
    models_list = []
    models_list.append(model_1)
    models_list.append(model_2)
    
    model_output_list = [model(model_input) for model in models_list]
    ensemble_output = tf.keras.layers.Maximum()(model_output_list)
    ensemble_model = tf.keras.Model(inputs=model_input, outputs=ensemble_output)
    
    return ensemble_model

# %%
ensemble_model = ensemble_model(conv_pool_cnn_model, vgg19_transfer_model)

# %%
ensemble_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv_pool_cnn (Functional)      (None, 43)           1759051     input_1[0][0]
# __________________________________________________________________________________________________
# vgg19_transfer (Functional)     (None, 43)           20595819    input_1[0][0]
# __________________________________________________________________________________________________
# maximum (Maximum)               (None, 43)           0           conv_pool_cnn[0][0]
#                                                                  vgg19_transfer[0][0]
# ==================================================================================================
# Total params: 22,354,870
# Trainable params: 22,353,526
# Non-trainable params: 1,344
# __________________________________________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_ensemble = train(ensemble_model, "sparse_categorical_crossentropy", "adam", "accuracy", 32, 30)
# Out:
# Epoch 1/30
# 858/858 [==============================] - 23s 26ms/step - loss: 0.1273 - accuracy: 0.9680 - val_loss: 0.1277 - val_accuracy: 0.9257
# Epoch 2/30
# 858/858 [==============================] - 22s 26ms/step - loss: 0.1089 - accuracy: 0.9724 - val_loss: 0.0497 - val_accuracy: 0.9904
# Epoch 3/30
# 858/858 [==============================] - 22s 25ms/step - loss: 0.1528 - accuracy: 0.9679 - val_loss: 0.4305 - val_accuracy: 0.9176
# Epoch 4/30
# 858/858 [==============================] - 22s 25ms/step - loss: 0.1870 - accuracy: 0.9633 - val_loss: 0.0749 - val_accuracy: 0.9839
# Epoch 5/30
# 858/858 [==============================] - 22s 25ms/step - loss: 0.1300 - accuracy: 0.9705 - val_loss: 0.0517 - val_accuracy: 0.9874
# Epoch 6/30
# 858/858 [==============================] - 21s 25ms/step - loss: 0.1526 - accuracy: 0.9649 - val_loss: 0.0508 - val_accuracy: 0.9880
# Epoch 7/30
# 858/858 [==============================] - 21s 24ms/step - loss: 0.1249 - accuracy: 0.9730 - val_loss: 0.1979 - val_accuracy: 0.9727
# Epoch 8/30
# 858/858 [==============================] - 21s 24ms/step - loss: 0.1310 - accuracy: 0.9716 - val_loss: 0.0724 - val_accuracy: 0.9856
# Epoch 9/30
# 858/858 [==============================] - 21s 25ms/step - loss: 0.1387 - accuracy: 0.9666 - val_loss: 0.0976 - val_accuracy: 0.9867
# Epoch 10/30
# 858/858 [==============================] - 21s 25ms/step - loss: 0.1173 - accuracy: 0.9737 - val_loss: 0.0926 - val_accuracy: 0.9710
# Epoch 11/30
# 858/858 [==============================] - 21s 24ms/step - loss: 0.1026 - accuracy: 0.9751 - val_loss: 0.0715 - val_accuracy: 0.9859
# Epoch 12/30
# 858/858 [==============================] - 21s 24ms/step - loss: 0.1309 - accuracy: 0.9687 - val_loss: 0.1742 - val_accuracy: 0.9683
# Epoch 13/30
# 858/858 [==============================] - 21s 24ms/step - loss: 0.1349 - accuracy: 0.9706 - val_loss: 0.0654 - val_accuracy: 0.9906
# Epoch 14/30
# 858/858 [==============================] - 21s 25ms/step - loss: 0.1219 - accuracy: 0.9711 - val_loss: 0.1429 - val_accuracy: 0.9636
# Epoch 15/30
# 858/858 [==============================] - 21s 24ms/step - loss: 0.1186 - accuracy: 0.9698 - val_loss: 0.0768 - val_accuracy: 0.9845
# Epoch 16/30
# 858/858 [==============================] - 21s 24ms/step - loss: 0.1103 - accuracy: 0.9762 - val_loss: 0.0806 - val_accuracy: 0.9797
# Epoch 17/30
# 858/858 [==============================] - 21s 24ms/step - loss: 0.1321 - accuracy: 0.9711 - val_loss: 0.1004 - val_accuracy: 0.9782
# Epoch 18/30
# 858/858 [==============================] - 21s 24ms/step - loss: 0.1271 - accuracy: 0.9716 - val_loss: 0.0516 - val_accuracy: 0.9922
# Epoch 19/30
# 858/858 [==============================] - 21s 24ms/step - loss: 0.1157 - accuracy: 0.9733 - val_loss: 0.1227 - val_accuracy: 0.9868
# Epoch 20/30
# 858/858 [==============================] - 21s 25ms/step - loss: 0.1160 - accuracy: 0.9715 - val_loss: 0.0878 - val_accuracy: 0.9867
# Epoch 21/30
# 858/858 [==============================] - 21s 25ms/step - loss: 0.1217 - accuracy: 0.9721 - val_loss: 0.0456 - val_accuracy: 0.9929
# Epoch 22/30
# 858/858 [==============================] - 21s 25ms/step - loss: 0.1058 - accuracy: 0.9751 - val_loss: 0.0904 - val_accuracy: 0.9847
# Epoch 23/30
# 858/858 [==============================] - 21s 25ms/step - loss: 0.1101 - accuracy: 0.9737 - val_loss: 0.0737 - val_accuracy: 0.9883
# Epoch 24/30
# 858/858 [==============================] - 21s 24ms/step - loss: 0.0871 - accuracy: 0.9789 - val_loss: 0.0503 - val_accuracy: 0.9918
# Epoch 25/30
# 858/858 [==============================] - 21s 24ms/step - loss: 0.0915 - accuracy: 0.9782 - val_loss: 0.0530 - val_accuracy: 0.9855
# Epoch 26/30
# 858/858 [==============================] - 21s 24ms/step - loss: 0.1237 - accuracy: 0.9729 - val_loss: 0.0541 - val_accuracy: 0.9897
# Epoch 27/30
# 858/858 [==============================] - 21s 25ms/step - loss: 0.1111 - accuracy: 0.9732 - val_loss: 0.0828 - val_accuracy: 0.9821
# Epoch 28/30
# 858/858 [==============================] - 21s 24ms/step - loss: 0.1279 - accuracy: 0.9718 - val_loss: 0.0473 - val_accuracy: 0.9909
# Epoch 29/30
# 858/858 [==============================] - 21s 24ms/step - loss: 0.1065 - accuracy: 0.9749 - val_loss: 0.0817 - val_accuracy: 0.9896
# Epoch 30/30
# 858/858 [==============================] - 21s 24ms/step - loss: 0.1235 - accuracy: 0.9682 - val_loss: 0.1127 - val_accuracy: 0.9794

# %% [markdown]
# ### Evaluate and predict on test set

# %%
score_ensemble = ensemble_model.evaluate(X_test, Y_test)
# Out:
# 395/395 [==============================] - 3s 7ms/step - loss: 0.3809 - accuracy: 0.9367

# %%
pred_ens = ensemble_model.predict(X_test)

# %% [markdown]
# ### Log loss

# %%
log_loss_score_ens = metrics.log_loss(Y_test, pred_ens)
print("Log loss score: {}".format(log_loss_score_ens))
# Out:
# Log loss score: 0.39751544617859985

# %% [markdown]
# ### Soft voting

# %%
### Here we predict the output based on the max probability for each class label obtained by combining the outputs of the CNN and the VG16 based model

softvoting = pred_vg + pred_Cnn
log_loss_softvoting = metrics.log_loss(Y_test, softvoting)
print("Log loss score: {}".format(log_loss_softvoting))
# Out:
# Log loss score: 0.19318166970575051
